# %% [markdown]
# <a href="https://colab.research.google.com/github/ilfpns/CUDA_study/blob/main/CUDA_Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Mar  9 09:05:28 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0             27W /   70W |       0MiB /  15360MiB |      2%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %%writefile helloCUDA.cu
# #include <stdio.h>
#
# __global__ void hello(){
#     printf("Hello CUDA\n");
# }
#
# int main() {
#     hello<<<1,110>>>();
#     cudaDeviceSynchronize();
# }
# Out:
# Overwriting helloCUDA.cu

# %%
# !nvcc helloCUDA.cu -o helloCUDA
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./helloCUDA
# Out:
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# Hello CUDA
# ...
